# %% [markdown]
# # 실전: 시카고 샌드위치 맛집 소개 사이트에 접근

# %%
from bs4 import BeautifulSoup
from urllib.request import Request, urlopen

# %%
url_base = 'https://www.chicagomag.com'
url_sub = '/Chicago-Magazine/November-2012/Best-Sandwiches-Chicago/'

# headers={'User-Agent': "Mozilla/5.0"} -> 크롤링 방지로 인한 봇이 아니에요
url = Request(url_base + url_sub, headers={'User-Agent': "Mozilla/5.0"})
html = urlopen(url)

# %%
soup = BeautifulSoup(html, 'html.parser')
# soup

# %%
# soup.find_all('div', 'sammy')

# %%
len(soup.find_all('div', 'sammy'))
# Out:
# 50

# %%
soup.find_all('div', 'sammy')[0]
# Out:
# <div class="sammy" style="position: relative;">
# <div class="sammyRank">1</div>
# <div class="sammyListing"><a href="/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/"><b>BLT</b><br/>
# Old Oak Tap<br/>
# <em>Read more</em> </a></div>
# </div>

# %% [markdown]
# ## 접근한 웹 페이지에서 원하는 데이터 추출하고 정리

# %%
# 맛집 1위 data 가져오기
tmp_one = soup.find_all('div', 'sammy')[0]
type(tmp_one)
# Out:
# bs4.element.Tag

# %%
# 1~50위 순위 class는 sammyRank로 되어 있음
tmp_one.find(class_='sammyRank')
# Out:
# <div class="sammyRank">1</div>

# %%
tmp_one.find(class_='sammyRank').get_text()
# Out:
# '1'

# %%
# sammyRank 안의 클래스 추출
tmp_one.find(class_='sammyListing')
# Out:
# <div class="sammyListing"><a href="/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/"><b>BLT</b><br/>
# Old Oak Tap<br/>
# <em>Read more</em> </a></div>

# %%
# sammyListing 안에 텍스트만 가져오기
tmp_one.find(class_='sammyListing').get_text()
# Out:
# 'BLT\nOld Oak Tap\nRead more '

# %%
# 링크 추출
tmp_one.find('a')['href']
# Out:
# '/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/'

# %% [markdown]
# ### 데이터 안의 '\n' 제거

# %%
# 정규식(Regular Express)
import re

tmp_string = tmp_one.find(class_='sammyListing').get_text()
# split : 지정한 특정 패턴이 일치하면 분리
re.split(('\n'), tmp_string)

print(re.split(('\n'), tmp_string)[0]) # 메뉴 이름
print(re.split(('\n'), tmp_string)[1]) # 가게 이름
# Out:
# BLT
# Old Oak Tap

# %% [markdown]
# ### 절대 경로로 잡힌 url은 그대로 두고 상대 경로로 잡힌 url은 절대 경로로 변경

# %%
from urllib.parse import urljoin

# %%
rank = [] # 순위
main_menu = [] # 메인 메뉴 이름
cafe_name = [] # 카페 이름
url_add = [] # 접근 주소
list_soup = soup.find_all('div', 'sammy')

for item in list_soup:
    rank.append(item.find(class_='sammyRank').get_text())
    tmp_string = item.find(class_='sammyListing').get_text()
    main_menu.append(re.split(('\n'), tmp_string)[0])
    cafe_name.append(re.split(('\n'), tmp_string)[1])
    url_add.append(urljoin(url_base, item.find('a')['href']))

# %%
rank[:5]
# Out:
# ['1', '2', '3', '4', '5']

# %%
cafe_name[:5]
# Out:
# ['Old Oak Tap', 'Au Cheval', 'Xoco', 'Al’s Deli', 'Publican Quality Meats']

# %% [markdown]
# ### 주피터 노트북에서 상태 진행바를 쉽게 만들어 주는 모듈
#  * pip install tqdm

# %%
from tqdm import tqdm_notebook
import time

rank = [] # 순위
main_menu = [] # 메인 메뉴 이름
cafe_name = [] # 카페 이름
url_add = [] # 접근 주소
list_soup = soup.find_all('div', 'sammy')
bar_total = tqdm_notebook(list_soup)


for item in bar_total:
    rank.append(item.find(class_='sammyRank').get_text())
    tmp_string = item.find(class_='sammyListing').get_text()
    main_menu.append(re.split(('\n'), tmp_string)[0])
    cafe_name.append(re.split(('\n'), tmp_string)[1])
    url_add.append(urljoin(url_base, item.find('a')['href']))
    
    # 크롤링 중 너무 빨리 긁어오는(누락 위험) 것을 방지하기 위해 0.05 만큼 대기
    time.sleep(0.05)
# Out:
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_8040\2583802767.py:9: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   bar_total = tqdm_notebook(list_soup)
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
len(rank),len(main_menu),len(cafe_name),len(url_add)
# Out:
# (50, 50, 50, 50)

# %%
import pandas as pd

data={'Rank':rank, 'Menu':main_menu, 'Cafe':cafe_name, 'URL':url_add}
df = pd.DataFrame(data)
df.head()
# Out:
#   Rank               Menu                    Cafe  \
# 0    1                BLT             Old Oak Tap
# 1    2      Fried Bologna               Au Cheval
# 2    3  Woodland Mushroom                    Xoco
# 3    4         Roast Beef               Al’s Deli
# 4    5               PB&L  Publican Quality Meats
#
#                                                  URL
# 0  https://www.chicagomag.com/Chicago-Magazine/No...
# 1  https://www.chicagomag.com/Chicago-Magazine/No...
# 2  https://www.chicagomag.com/Chicago-Magazine/No...
# 3  https://www.chicagomag.com/Chicago-Magazine/No...
# 4  https://www.chicagomag.com/Chicago-Magazine/No...

# %%
df.to_csv('../../data/best_sandwiches_chicago11.csv', sep=',',
         encoding='UTF-8')

# %% [markdown]
# # 다수의 웹 페이지에 접근 원하는 정보 가져오기

# %%
df = pd.read_csv('../../data/best_sandwiches_chicago11.csv', index_col=0)
df.head()
# Out:
#    Rank               Menu                    Cafe  \
# 0     1                BLT             Old Oak Tap
# 1     2      Fried Bologna               Au Cheval
# 2     3  Woodland Mushroom                    Xoco
# 3     4         Roast Beef               Al’s Deli
# 4     5               PB&L  Publican Quality Meats
#
#                                                  URL
# 0  https://www.chicagomag.com/Chicago-Magazine/No...
# 1  https://www.chicagomag.com/Chicago-Magazine/No...
# 2  https://www.chicagomag.com/Chicago-Magazine/No...
# 3  https://www.chicagomag.com/Chicago-Magazine/No...
# 4  https://www.chicagomag.com/Chicago-Magazine/No...

# %%
df['URL'][0]
# Out:
# 'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/'

# %%
# url = Request(df['URL'][0], headers={'User-Agent':'Mozilla/5.0'})
# html = urlopen(url)
# soup_tmp = BeautifulSoup(html, "html.parser")
# # soup_tmp

# %%
print(soup_tmp.find('p','addy'))
# Out:
# <p class="addy">
# <em>$10. 2109 W. Chicago Ave., 773-772-0406, <a href="http://www.theoldoaktap.com/">theoldoaktap.com</a></em></p>

# %%
price_tmp = soup_tmp.find('p','addy').get_text()
price_tmp
# Out:
# '\n$10. 2109 W. Chicago Ave., 773-772-0406, theoldoaktap.com'

# %%
price_tmp.split()
# Out:
# ['$10.', '2109', 'W.', 'Chicago', 'Ave.,', '773-772-0406,', 'theoldoaktap.com']

# %%
# 10 뒤에 . 제거
price_tmp.split()[0][:-1]
# Out:
# '$10'

# %%
price_tmp.split()[1:-2]
# Out:
# ['2109', 'W.', 'Chicago', 'Ave.,']

# %%
' '.join(price_tmp.split()[1:-2])
# Out:
# '2109 W. Chicago Ave.,'

# %% [markdown]
# # 샌드위치페이지 50개에 접근

# %%
from tqdm import tqdm_notebook
import time

price = []
address = []

for n in tqdm_notebook(df.index):
    url = Request(df['URL'][n], headers={'User-Agent':'Mozilla/5.0'})
    html = urlopen(url)
    soup_tmp = BeautifulSoup(html, "lxml")
    
    gettings = soup_tmp.find('p','addy').get_text()
    
    price.append(gettings.split()[0][:-1])
    address.append(' '.join(gettings.split()[1:-2]))
# Out:
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_8040\390610935.py:7: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for n in tqdm_notebook(df.index):
#   0%|          | 0/50 [00:00<?, ?it/s]

# %% [markdown]
# # 50개 웹 페이지에 대한 정보 가져오기

# %%
df['Price'] = price
df['Address'] = address
df = df.loc[:, ['Rank', 'Cafe', 'Menu', 'Price', 'Address']]
df.set_index('Rank', inplace=True)
df.head()
# Out:
#                         Cafe               Menu  Price  \
# Rank
# 1                Old Oak Tap                BLT    $10
# 2                  Au Cheval      Fried Bologna     $9
# 3                       Xoco  Woodland Mushroom  $9.50
# 4                  Al’s Deli         Roast Beef  $9.40
# 5     Publican Quality Meats               PB&L    $10
#
#                        Address
# Rank
# 1        2109 W. Chicago Ave.,
# 2         800 W. Randolph St.,
# 3            445 N. Clark St.,
# 4     914 Noyes St., Evanston,
# 5          825 W. Fulton Mkt.,

# %%
df.to_csv('../../data/best_sandwiches_chicago22.csv', sep=',',
         encoding='UTF-8')

# %% [markdown]
#   # 맛집 위치를 지도에 표시

# %%
import folium
import pandas as pd
import googlemaps
import numpy as np

# %%
df=pd.read_csv('../../data/03. best_sandwiches_list_chicago2.csv', index_col=0)
df.head()
# Out:
#                         Cafe               Menu  Price  \
# Rank
# 1                Old Oak Tap                BLT    $10
# 2                  Au Cheval      Fried Bologna     $9
# 3                       Xoco  Woodland Mushroom  $9.50
# 4                  Al’s Deli         Roast Beef  $9.40
# 5     Publican Quality Meats               PB&L    $10
#
#                        Address
# Rank
# 1        2109 W. Chicago Ave.,
# 2         800 W. Randolph St.,
# 3            445 N. Clark St.,
# 4     914 Noyes St., Evanston,
# 5          825 W. Fulton Mkt.,

# %%
# gmaps_key = "본인 API"
# gmaps = googlemaps.Client(key=gmaps_key)

# %%
lat = []
lng = []
for n in tqdm_notebook(df.index):
    if df['Address'][n] != 'Multiple':
        target_name = df['Address'][n]+', '+'Chicago'
        gmaps_output = gmaps.geocode(target_name)
        location_output = gmaps_output[0].get('geometry')
        
        lat.append(location_output['location']['lat'])
        lng.append(location_output['location']['lng'])
        
    else:
        lat.append(np.nan)
        lng.append(np.nan)

df['lat'] = lat
df['lng'] = lng
df.head()
# Out:
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_8040\1548284059.py:3: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for n in tqdm_notebook(df.index):
#   0%|          | 0/50 [00:00<?, ?it/s]
#                         Cafe               Menu  Price  \
# Rank
# 1                Old Oak Tap                BLT    $10
# 2                  Au Cheval      Fried Bologna     $9
# 3                       Xoco  Woodland Mushroom  $9.50
# 4                  Al’s Deli         Roast Beef  $9.40
# 5     Publican Quality Meats               PB&L    $10
#
#                        Address        lat        lng
# Rank
# 1        2109 W. Chicago Ave.,  41.895558 -87.679967
# 2         800 W. Randolph St.,  41.884639 -87.647590
# 3            445 N. Clark St.,  41.890523 -87.630783
# 4     914 Noyes St., Evanston,  42.058322 -87.683748
# 5          825 W. Fulton Mkt.,  41.886604 -87.648536

# %%
mapping = folium.Map(location=[df['lat'].mean(), df['lng'].mean()],
                    zoom_start=11)

for n in df.index:
    if df['Address'][n] != 'Multiple':
        folium.Marker([df['lat'][n], df['lng'][n]],
                     popup=df['Cafe'][n]).add_to(mapping)
mapping
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_522dafae5dd5641aabf575e205de7833 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_522dafae5dd5641aabf575e205de7833&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_522dafae5dd5641aabf575e205de7833 = L.map(
#                 &quot;map_522dafae5dd5641aabf575e205de7833&quot;,
#                 {
#                     center: [41.909424086363636, -87.67221806590908],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_37ee7199a2111535c4623fbd876b8bba = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_522dafae5dd5641aabf575e205de7833);
#
#
#             var marker_3130e58bab93ea37d46009e9ee87111a = L.marker(
#                 [41.8955577, -87.6799673],
#                 {}
#             ).addTo(map_522dafae5dd5641aabf575e205de7833);
#
#
#         var popup_aaef59df27bf977e100d58298ed81f3e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9139caf955c661992037ade6aab468ed = $(`&lt;div id=&quot;html_9139caf955c661992037ade6aab468ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Old Oak Tap&lt;/div&gt;`)[0];
#                 popup_aaef59df27bf977e100d58298ed81f3e.setContent(html_9139caf955c661992037ade6aab468ed);
#
#
#
#         marker_3130e58bab93ea37d46009e9ee87111a.bindPopup(popup_aaef59df27bf977e100d58298ed81f3e)
#         ;
#
#
#
#
#             var marker_de66f36ea3520c120cf47d4b112769e0 = L.marker(
#                 [41.8846392, -87.6475897],
#                 {}
#             ).addTo(map_522dafae5dd5641aabf575e205de7833);
#
#
#         var popup_79489febcfae73b0892c9323ad4b97b6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8c9849b02de98d044aacb131a7fc2e9c = $(`&lt;div id=&quot;html_8c9849b02de98d044aacb131a7fc2e9c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Au Cheval&lt;/div&gt;`)[0];
#                 popup_79489febcfae73b0892c9323ad4b97b6.setContent(html_8c9849b02de98d044aacb131a7fc2e9c);
#
#
#
#         marker_de66f36ea3520c120cf47d4b112769e0.bindPopup(popup_79489febcfae73b0892c9323ad4b97b6)
#         ;
#
#
#
#
#             var marker_349b3ab248d031fe3fb003b1edbbde3c = L.marker(
#                 [41.8905226, -87.6307834],
#                 {}
#             ).addTo(map_522dafae5dd5641aabf575e205de7833);
#
#
#         var popup_98f7786559c2ff4dde93704cfde83de3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_adf600610ab8b211352ca1d4471f6806 = $(`&lt;div id=&quot;html_adf600610ab8b211352ca1d4471f6806&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Xoco&lt;/div&gt;`)[0];
#                 popup_98f7786559c2ff4dde93704cfde83de3.setContent(html_adf600610ab8b211352ca1d4471f6806);
#
#
#
#         marker_349b3ab248d031fe3fb003b1edbbde3c.bindPopup(popup_98f7786559c2ff4dde93704cfde83de3)
#         ;
#
#
#
#
#             var marker_4d5244249968aab994077abaea8d50d7 = L.marker(
#                 [42.0583217, -87.6837479],
#                 {}
#             ).addTo(map_522dafae5dd5641aabf575e205de7833);
#
#
#         var popup_244f6c3761b5839504613f5184e99056 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_52e3c2422a847c03bdd0d5283664af86 = $(`&lt;div id=&quot;html_52e3c2422a847c03bdd0d5283664af86&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Al’s Deli&lt;/div&gt;`)[0];
#                 popup_244f6c3761b5839504613f5184e99056.setContent(html_52e3c2422a847c03bdd0d5283664af86);
#
#
#
#         marker_4d5244249968aab994077abaea8d50d7.bindPopup(popup_244f6c3761b5839504613f5184e99056)
#         ;
#
#
#
#
#             var marker_00d94b7cb26e94d3c9195c52df87d935 = L.marker(
#                 [41.8866036, -87.64853649999999],
#                 {}
#             ).addTo(map_522dafae5dd5641aabf575e205de7833);
#
#
#         var popup_23dd7cddf0b92121301a6dc200c639a4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a56cf9d9a6d9db740efbf2eefc28eaec = $(`&lt;div id=&quot;html_a56cf9d9a6d9db740efbf2eefc28eaec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Publican Quality Meats&lt;/div&gt;`)[0];
#                 popup_23dd7cddf0b92121301a6dc200c639a4.setContent(html_a56cf9d9a6d9db740efbf2eefc28eaec);
#
#
#
#         marker_00d94b7cb26e94d3c9195c52df87d935.bindPopup(popup_23dd7cddf0b92121301a6dc200c639a4)
#         ;
#
#
#
#
#             var marker_e4c9c157c22002b577bff1d95d6e5288 = L.marker(
#                 [41.900250

# %%
# 샌드위치 가게에 MarkerCluster를 추가
from folium.plugins import MarkerCluster
mc = MarkerCluster().add_to(mapping)
mapping = folium.Map(location=[df['lat'].mean(), df['lng'].mean()],
                    zoom_start=11)

for n in df.index:
    if df['Address'][n] != 'Multiple':
        folium.Marker([df['lat'][n], df['lng'][n]],
                     popup=df['Cafe'][n]).add_to(mapping)
        
        mc.add_child(folium.Marker([df['lat'][n],
                                    df['lng'][n]],
                                    popup=df['Cafe'][n])).add_to(mapping)
                                    
mapping
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9a8afa7b1fa7d289e2657b49c2833ed3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9a8afa7b1fa7d289e2657b49c2833ed3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9a8afa7b1fa7d289e2657b49c2833ed3 = L.map(
#                 &quot;map_9a8afa7b1fa7d289e2657b49c2833ed3&quot;,
#                 {
#                     center: [41.909424086363636, -87.67221806590908],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b80fc8203ece11440b8771aefdf5b12b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9a8afa7b1fa7d289e2657b49c2833ed3);
#
#
#             var marker_6ef08ec520eb94a4e15e123fd5889f44 = L.marker(
#                 [41.8955577, -87.6799673],
#                 {}
#             ).addTo(map_9a8afa7b1fa7d289e2657b49c2833ed3);
#
#
#         var popup_4e91848d69a2caf941bcf27bbf9421c6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_02ce13a3794b39c8d887267fd9d54d74 = $(`&lt;div id=&quot;html_02ce13a3794b39c8d887267fd9d54d74&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Old Oak Tap&lt;/div&gt;`)[0];
#                 popup_4e91848d69a2caf941bcf27bbf9421c6.setContent(html_02ce13a3794b39c8d887267fd9d54d74);
#
#
#
#         marker_6ef08ec520eb94a4e15e123fd5889f44.bindPopup(popup_4e91848d69a2caf941bcf27bbf9421c6)
#         ;
#
#
#
#
#             var marker_cluster_16e00e94d7db32a519c37742b8fee67d = L.markerClusterGroup(
#                 {}
#             );
#             map_9a8afa7b1fa7d289e2657b49c2833ed3.addLayer(marker_cluster_16e00e94d7db32a519c37742b8fee67d);
#
#
#             var marker_ed114edfd33bd7b2ba1b0f505efe874a = L.marker(
#                 [41.8955577, -87.6799673],
#                 {}
#             ).addTo(marker_cluster_16e00e94d7db32a519c37742b8fee67d);
#
#
#         var popup_b5f10a3ebf888232c63b0c3317cad836 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b0004780a25e0df3a0fe24a637c8510e = $(`&lt;div id=&quot;html_b0004780a25e0df3a0fe24a637c8510e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Old Oak Tap&lt;/div&gt;`)[0];
#                 popup_b5f10a3ebf888232c63b0c3317cad836.setContent(html_b0004780a25e0df3a0fe24a637c8510e);
#
#
#
#         marker_ed114edfd33bd7b2ba1b0f505efe874a.bindPopup(popup_b5f10a3ebf888232c63b0c3317cad836)
#         ;
#
#
#
#
#             var marker_35a3f8b4acc4a57638bea5f43dbc1b79 = L.marker(
#                 [41.8846392, -87.6475897],
#                 {}
#             ).addTo(marker_cluster_16e00e94d7db32a519c37742b8fee67d);
#
#
#         var popup_0cba4eac8bc9774d71b74d587d5f4ffb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7b64197e12aaf86df1c83feffb187c6a = $(`&lt;div id=&quot;html_7b64197e12aaf86df1c83feffb187c6a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Au Cheval&lt;/div&gt;`)[0];
#                 popup_0cba4eac8bc9774d71b74d587d5f4ffb.setContent(html_7b64197e12aaf86df1c83feffb187c6a);
#
#
#
#         marker_35a3f8b4acc4a57638bea5f43dbc1b79.bindPopup(popup_0cba4eac8bc9774d71b74d587d5f4ffb)
#         ;
#
#
#
#
#             var marker_60c3c454d30f76d64f2561fd559caa21 = L.marker(
#                 [41.8905226, -87.6307834],
#                 {}
#             ).addTo(marker_cluster_16e00e94d7db32a519c37742b8fee67d);
#
#
#         var popup_a1498f6b8a686d6f345d0a6a6b61a8e4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8e8cdace45825d831e619be9ffe4186f = $(`&lt;div id=&quot;html_8e8cdace45825d831e619be9ffe4186f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Xoco&lt;/div&gt;`)[0];
#                 popup_a1498f6b8a686d6f345d0a6a6b61a8e4.setContent(html_8e8cdace45825d831e619be9ffe4186f);
#
#
#
#         marker_60c3c454d30f76d64f2561fd559caa21.bindPopup(popup_a1498f6b8a686d6f345d0a6a6b61a8e4)
#         ;
#
#
#
#
#             var marker_3e333d99f9780d748b2b9f34d184c4e6 = L.marker(
#                 [42.0583217, -87.6837479],
#                 {}
#             ).addTo(marker_cluster_16e00e94d7db32a51
